# %%
import os
import sys
sys.path.insert(0, os.getcwd()+'/src')
import numpy as np
import autograd.numpy as anp
from scipy import optimize
np.set_printoptions(suppress=True)
np.set_printoptions(linewidth=200)
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from IPython.display import display, HTML
display(HTML("<style>.container { width:97% !important; }</style>"))
pd.options.display.float_format = '{:.3g}'.format
sns.set(font_scale = 1.4, rc={"grid.linewidth": 1,'grid.color': '#b0b0b0', 'axes.edgecolor': 'black',"lines.linewidth": 3.0}, style = 'whitegrid')
palette = sns.color_palette("bright")
sns.set_palette(palette)
# Out:
# <style>.container { width:97% !important; }</style>

# %%
lsp = np.load("output/para_0053_model_asym_HS.npz")
def trans(x):
    return np.exp(x)/(np.exp(x)+1)
def read_csv(name):
    h1 = pd.DataFrame(lsp[name])
    h1.index = trans(np.linspace(-18,18,1001))
    h1.columns = np.linspace(-1,1,201)
    return h1
h1 = read_csv('h1')
h2 = read_csv('h2')
hz = read_csv('hz')

# %%
alpha_z_tilde_ex = -0.0025
ell_ex = 0.11
filename_ell = "azt_"+str(alpha_z_tilde_ex).replace(".","")[:5]+"_ell_ex_"+str(ell_ex).replace(".","")[:3]+"_"
filename_ell
# Out:
# 'azt_-0002_ell_ex_011_'

# %%
str(ell_ex).replace(".","")[:3]
# Out:
# '011'

# %%
fig, ax = plt.subplots(1,1,figsize = (8,8))
sns.lineplot(data = h1[0],label = r"$-H_1$")
sns.lineplot(data = h2[0],label = r"$-H_2$")
sns.lineplot(data = hz[0],label = r"$-H_z$")
fig.tight_layout()
# fig.savefig('H.png', dpi = 1200)
ax.set_title(r'$-H$')
plt.show()

# %%
gt = pd.DataFrame(lsp['g'])
gt.index = trans(np.linspace(-18,18,1001))
gt.columns = np.linspace(-1,1,201)
g_R = gt.sum(axis=1)*0.01
g_Z = gt.sum(axis=0)*0.036
plt.plot(g_R)

# gt = pd.read_csv('g_1.csv',header = None)
# gt.index = trans(np.linspace(-18,18,1001))
# gt.columns = np.linspace(-1,1,201)
# g_R2 = gt.sum(axis=1)*0.01
# g_Z2 = gt.sum(axis=0)*0.036
# plt.plot(g_R2)

# %%
plt.plot(g_Z)
plt.plot(g_Z2)

# %%
str(round(0.1245,4)).replace(".","")
# Out:
# '01245'

# %%
np.max(g_R-g_R2)
# Out:
# 0.3915183456491783

# %%
np.sum(np.array(g_Z)*(np.linspace(-1,1,201))**2)*0.01
# Out:
# 0.027299168573691746

# %%
np.sum(np.array(g_R)*(np.linspace(0,1,1001))**2)*0.036
# Out:
# 0.2506166657403047

# %%
# sigma_z = np.array([0.011, 0.025])
sigma_z = np.array([0.011*np.sqrt(0.5)   , 0.011*np.sqrt(0.5)   , 0.025])
kappa_hat = 0.014

np.sqrt(np.linalg.norm(sigma_z)**2/kappa_hat/2)
# Out:
# 0.16322639842518474

# %%
1.64*np.sqrt(np.linalg.norm(sigma_z)**2/kappa_hat/2)
# Out:
# 0.26769129341730297

# %%
gt.columns[73]
# Out:
# -0.27

# %%
1.64*np.sqrt(np.sum(gt.sum(axis=0)*0.036*0.01*np.linspace(-1,1,201)**2))
# Out:
# 0.270968344637925

# %%
def read_csv(name):
    h1 = pd.DataFrame(lsp[name])
    h1.index = trans(np.linspace(-18,18,1001))
    h1.columns = np.linspace(-1,1,201)
    return h1

# %%
h1 = read_csv('h1')
h2 = read_csv('h2')
hz = read_csv('hz')
d1 = read_csv('d1')
d2 = read_csv('d2')
# h12 = read_csv('h12')
# h22 = read_csv('h22')
# hz2 = read_csv('hz2')
# d12 = read_csv('d12')
# d22 = read_csv('d22')

# %% [markdown]
# 1/4

# %%
fig, axes = plt.subplots(2,2,figsize = (12,8))
axes = axes.flatten()
sns.lineplot(d1.iloc[:-10,100], ax = axes[0], label = 'Z = 0', color = 'red')
sns.lineplot(d2.iloc[10:,100], ax = axes[1], label = 'Z = 0', color = 'red')
sns.lineplot(d1.iloc[:-10,127], ax = axes[0], label = r'$Z =  +1.64\sigma$', color = 'blue')
sns.lineplot(d2.iloc[10:,127], ax = axes[1], label = r'$Z =  +1.64\sigma$', color = 'blue')
sns.lineplot(d1.iloc[:-10,73], ax = axes[0], label = r'$Z =  -1.64\sigma$', color = 'green')
sns.lineplot(d2.iloc[10:,73], ax = axes[1], label = r'$Z =  -1.64\sigma$', color = 'green')

sns.lineplot(h1[0], ax = axes[2], label = '$-H_1$', color = 'red')
sns.lineplot(h2[0], ax = axes[2], label = '$-H_2$', color = 'blue')
sns.lineplot(hz[0], ax = axes[2], label = '$-H_z$', color = 'green')

sns.lineplot(g_R, ax = axes[3], color = 'red')


axes[0].set_title(r'${I^1}/{K^1}$')
axes[1].set_title(r'${I^2}/{K^2}$')
axes[2].set_title(r'$-H$')
axes[3].set_title('R stationary density')

# axes[0,1].set_title('I_1/K_1')
# axes[1,0].set_title('I_2/K_2')
# axes[1,1].set_title(r'h')
# axes[0].set_ylim([0.03,0.036])
# axes[1].set_ylim([0.03,0.036])
# axes[2].set_ylim([-0.01,0.18])
# axes[1,1].set_ylim([-0.01,0.09])

for ax in axes:
    ax.set_ylabel('')
# fig.suptitle('Symmetric Case')
fig.tight_layout()
# fig.savefig('No titile Symmtric Case.png', dpi = 1200)
plt.show()

# %% [markdown]
# 1/9

# %%
fig, axes = plt.subplots(2,2,figsize = (12,8))
axes = axes.flatten()
sns.lineplot(d1.iloc[:-10,100], ax = axes[0], label = 'Z = 0', color = 'red')
sns.lineplot(d2.iloc[10:,100], ax = axes[1], label = 'Z = 0', color = 'red')
sns.lineplot(d1.iloc[:-10,127], ax = axes[0], label = r'$Z =  +1.64\sigma$', color = 'blue')
sns.lineplot(d2.iloc[10:,127], ax = axes[1], label = r'$Z =  +1.64\sigma$', color = 'blue')
sns.lineplot(d1.iloc[:-10,73], ax = axes[0], label = r'$Z =  -1.64\sigma$', color = 'green')
sns.lineplot(d2.iloc[10:,73], ax = axes[1], label = r'$Z =  -1.64\sigma$', color = 'green')

sns.lineplot(h1[0], ax = axes[2], label = '$-H_1$', color = 'red')
sns.lineplot(h2[0], ax = axes[2], label = '$-H_2$', color = 'blue')
sns.lineplot(hz[0], ax = axes[2], label = '$-H_z$', color = 'green')

sns.lineplot(g_R, ax = axes[3], color = 'red')


axes[0].set_title(r'${I^1}/{K^1}$')
axes[1].set_title(r'${I^2}/{K^2}$')
axes[2].set_title(r'$-H$')
axes[3].set_title('R stationary density')

# axes[0,1].set_title('I_1/K_1')
# axes[1,0].set_title('I_2/K_2')
# axes[1,1].set_title(r'h')
# axes[0].set_ylim([0.03,0.036])
# axes[1].set_ylim([0.03,0.036])
# axes[2].set_ylim([-0.01,0.18])
# axes[1,1].set_ylim([-0.01,0.09])

for ax in axes:
    ax.set_ylabel('')
# fig.suptitle('Symmetric Case')
fig.tight_layout()
# fig.savefig('No titile Symmtric Case.png', dpi = 1200)
plt.show()

# %% [markdown]
# 1/19

# %%
fig, axes = plt.subplots(2,2,figsize = (12,8))
axes = axes.flatten()
sns.lineplot(d1.iloc[:-10,100], ax = axes[0], label = 'Z = 0', color = 'red')
sns.lineplot(d2.iloc[10:,100], ax = axes[1], label = 'Z = 0', color = 'red')
sns.lineplot(d1.iloc[:-10,127], ax = axes[0], label = r'$Z =  +1.64\sigma$', color = 'blue')
sns.lineplot(d2.iloc[10:,127], ax = axes[1], label = r'$Z =  +1.64\sigma$', color = 'blue')
sns.lineplot(d1.iloc[:-10,73], ax = axes[0], label = r'$Z =  -1.64\sigma$', color = 'green')
sns.lineplot(d2.iloc[10:,73], ax = axes[1], label = r'$Z =  -1.64\sigma$', color = 'green')

sns.lineplot(h1[0], ax = axes[2], label = '$-H_1$', color = 'red')
sns.lineplot(h2[0], ax = axes[2], label = '$-H_2$', color = 'blue')
sns.lineplot(hz[0], ax = axes[2], label = '$-H_z$', color = 'green')

sns.lineplot(g_R, ax = axes[3], color = 'red')


axes[0].set_title(r'${I^1}/{K^1}$')
axes[1].set_title(r'${I^2}/{K^2}$')
axes[2].set_title(r'$-H$')
axes[3].set_title('R stationary density')

# axes[0,1].set_title('I_1/K_1')
# axes[1,0].set_title('I_2/K_2')
# axes[1,1].set_title(r'h')
# axes[0].set_ylim([0.03,0.036])
# axes[1].set_ylim([0.03,0.036])
# axes[2].set_ylim([-0.01,0.18])
# axes[1,1].set_ylim([-0.01,0.09])

for ax in axes:
    ax.set_ylabel('')
# fig.suptitle('Symmetric Case')
fig.tight_layout()
# fig.savefig('No titile Symmtric Case.png', dpi = 1200)
plt.show()

# %%
fig, axes = plt.subplots(2,3,figsize = (22,8))
sns.lineplot(g_R, ax = axes[0,0])
sns.lineplot(d1[0], ax = axes[0,1], label = 'Z = 0')
sns.lineplot(d2[0], ax = axes[0,2], label = 'Z = 0')
sns.lineplot(h1[0], ax = axes[1,0], label = 'Z = 0')
sns.lineplot(h2[0], ax = axes[1,0], label = 'Z = 0')
sns.lineplot(hz[0], ax = axes[1,0], label = 'Z = 0')
sns.lineplot(d1.iloc[:,117], ax = axes[0,1], label = 'Z = Z + std')
sns.lineplot(d2.iloc[:,117], ax = axes[0,2], label = 'Z = Z + std')
sns.lineplot(h1.iloc[:,117], ax = axes[1,0], label = 'Z = Z + std')
sns.lineplot(h2.iloc[:,117], ax = axes[1,0], label = 'Z = Z + std')
sns.lineplot(hz.iloc[:,117], ax = axes[1,0], label = 'Z = Z + std')
sns.lineplot(d1.iloc[:,83], ax = axes[0,1], label = 'Z = Z - std')
sns.lineplot(d2.iloc[:,83], ax = axes[0,2], label = 'Z = Z - std')
sns.lineplot(h1.iloc[:,83], ax = axes[1,0], label = 'Z = Z - std')
sns.lineplot(h2.iloc[:,83], ax = axes[1,0], label = 'Z = Z - std')
sns.lineplot(hz.iloc[:,83], ax = axes[1,0], label = 'Z = Z - std')
axes[0,0].set_title('R stationary distribution')
axes[0,1].set_title(r'$\frac{I^1}{K^1}$')
axes[0,2].set_title(r'$\frac{I^2}{K^2}$')
axes[1,0].set_title(r'$h_1$')
axes[1,1].set_title(r'$h_2$')
axes[1,2].set_title(r'$h_z$')
axes[0,1].set_ylim([0.031,0.035])
axes[0,2].set_ylim([0.031,0.035])
axes[1,0].set_ylim([-0.01,0.09])
axes[1,1].set_ylim([-0.01,0.09])
axes[1,2].set_ylim([-0.01,0.09])
axes = axes.flatten()
for ax in axes:
    ax.set_ylabel('')
fig.suptitle('Asymmetric Case')
fig.tight_layout()
# fig.savefig('Exposure Elasticity, Consumption, epsilon, Approach 1.png', dpi = 1200)
plt.show()

# %%
d1
# Out:
#           -1     -0.99  -0.98  -0.97  -0.96  -0.95  -0.94  -0.93  -0.92  \
# 1.52e-08 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318
# 1.58e-08 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318
# 1.64e-08 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318
# 1.7e-08  0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318
# 1.76e-08 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318 0.0318
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1        0.0334 0.0334 0.0334 0.0334 0.0334 0.0334 0.0334 0.0334 0.0334
# 1        0.0334 0.0334 0.0334 0.0334 0.0334 0.0334 0.0334 0.0334 0.0334
# 1        0.0334 0.0334 0.0334 0.0334 0.0334 0.0334 0.0334 0.0334 0.0334
# 1        0.0332 0.0332 0.0332 0.0332 0.0332 0.0332 0.0332 0.0332 0.0332
# 1        0.0325 0.0325 0.0325 0.0325 0.0325 0.0325 0.0325 0.0325 0.0325
#
#           -0.91  ...  0.91   0.92   0.93   0.94   0.95   0.96   0.97   0.98   \
# ...

# %%
fig, axes = plt.subplots(2,2,figsize = (12,8))
axes = axes.flatten()
sns.lineplot(d1.iloc[:-10,100], ax = axes[0], label = 'Z = 0')
sns.lineplot(d2.iloc[10:,100], ax = axes[1], label = 'Z = 0')
sns.lineplot(d1.iloc[:-10,127], ax = axes[0], label = r'$Z =  +\sigma$')
sns.lineplot(d2.iloc[10:,127], ax = axes[1], label = r'$Z =  +\sigma$')
sns.lineplot(d1.iloc[:-10,73], ax = axes[0], label = r'$Z =  -\sigma$')
sns.lineplot(d2.iloc[10:,73], ax = axes[1], label = r'$Z =  -\sigma$')

sns.lineplot(h1[0], ax = axes[2], label = '$h_1$')
sns.lineplot(h2[0], ax = axes[2], label = '$h_2$')
sns.lineplot(hz[0], ax = axes[2], label = '$h_z$')

sns.lineplot(g_R, ax = axes[3])


axes[0].set_title(r'${I^1}/{K^1}$')
axes[1].set_title(r'${I^2}/{K^2}$')
axes[2].set_title(r'$h$')
axes[3].set_title('R stationary distribution')

# axes[0,1].set_title('I_1/K_1')
# axes[1,0].set_title('I_2/K_2')
# axes[1,1].set_title(r'h')
# axes[0,1].set_ylim([0.031,0.035])
# axes[1,0].set_ylim([0.031,0.035])
# axes[1,1].set_ylim([-0.01,0.09])

for ax in axes:
    ax.set_ylabel('')
fig.suptitle('Symmetric Case')
fig.tight_layout()
# fig.savefig('Exposure Elasticity, Consumption, epsilon, Approach 1.png', dpi = 1200)
plt.show()

# %%
fig, axes = plt.subplots(2,2,figsize = (12,8))
axes = axes.flatten()
sns.lineplot(d12.iloc[:-10,100], ax = axes[0], label = 'Z = 0')
sns.lineplot(d22.iloc[10:,100], ax = axes[1], label = 'Z = 0')
sns.lineplot(d12.iloc[:-10,127], ax = axes[0], label = r'$Z =  +\sigma$')
sns.lineplot(d22.iloc[10:,127], ax = axes[1], label = r'$Z =  +\sigma$')
sns.lineplot(d12.iloc[:-10,73], ax = axes[0], label = r'$Z =  -\sigma$')
sns.lineplot(d22.iloc[10:,73], ax = axes[1], label = r'$Z =  -\sigma$')

sns.lineplot(h12[0], ax = axes[2], label = '$h_1$')
sns.lineplot(h22[0], ax = axes[2], label = '$h_2$')
sns.lineplot(hz2[0], ax = axes[2], label = '$h_z$')

sns.lineplot(g_R2, ax = axes[3])


axes[0].set_title(r'${I^1}/{K^1}$')
axes[1].set_title(r'${I^2}/{K^2}$')
axes[2].set_title(r'$h$')
axes[3].set_title('R stationary distribution')

# axes[0,1].set_title('I_1/K_1')
# axes[1,0].set_title('I_2/K_2')
# axes[1,1].set_title(r'h')
# axes[0,1].set_ylim([0.031,0.035])
# axes[1,0].set_ylim([0.031,0.035])
# axes[1,1].set_ylim([-0.01,0.09])

for ax in axes:
    ax.set_ylabel('')
fig.suptitle('Asymmetric Case')
fig.tight_layout()
# fig.savefig('Exposure Elasticity, Consumption, epsilon, Approach 1.png', dpi = 1200)
plt.show()

# %%
fig, axes = plt.subplots(2,3,figsize = (22,8))
sns.lineplot(g_R2, ax = axes[0,0])
sns.lineplot(d12[0], ax = axes[0,1], label = 'Z = 0')
sns.lineplot(d22[0], ax = axes[0,2], label = 'Z = 0')
sns.lineplot(h12[0], ax = axes[1,0], label = 'Z = 0')
sns.lineplot(h22[0], ax = axes[1,1], label = 'Z = 0')
sns.lineplot(hz2[0], ax = axes[1,2], label = 'Z = 0')
sns.lineplot(d12.iloc[:,117], ax = axes[0,1], label = 'Z = Z + std')
sns.lineplot(d22.iloc[:,117], ax = axes[0,2], label = 'Z = Z + std')
sns.lineplot(h12.iloc[:,117], ax = axes[1,0], label = 'Z = Z + std')
sns.lineplot(h22.iloc[:,117], ax = axes[1,1], label = 'Z = Z + std')
sns.lineplot(hz2.iloc[:,117], ax = axes[1,2], label = 'Z = Z + std')
sns.lineplot(d12.iloc[:,83], ax = axes[0,1], label = 'Z = Z - std')
sns.lineplot(d22.iloc[:,83], ax = axes[0,2], label = 'Z = Z - std')
sns.lineplot(h12.iloc[:,83], ax = axes[1,0], label = 'Z = Z - std')
sns.lineplot(h22.iloc[:,83], ax = axes[1,1], label = 'Z = Z - std')
sns.lineplot(hz2.iloc[:,83], ax = axes[1,2], label = 'Z = Z - std')
axes[0,0].set_title('R stationary distribution')
axes[0,1].set_title(r'$\frac{I^1}{K^1}$')
axes[0,2].set_title(r'$\frac{I^2}{K^2}$')
axes[1,0].set_title(r'$h_1$')
axes[1,1].set_title(r'$h_2$')
axes[1,2].set_title(r'$h_z$')
axes[1,0].set_ylim([-0.01,0.09])
axes[1,1].set_ylim([-0.01,0.09])
axes[1,2].set_ylim([-0.01,0.09])
axes = axes.flatten()
for ax in axes:
    ax.set_ylabel('')

fig.suptitle('Symmetric Case')
fig.tight_layout()
# fig.savefig('Exposure Elasticity, Consumption, epsilon, Approach 1.png', dpi = 1200)
plt.show()
